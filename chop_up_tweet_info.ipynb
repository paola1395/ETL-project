# %%
import pandas as pd

# %%
df = pd.read_csv('tweet_info.csv')
df
# Out:
#                     tweet_id ticker_symbol
# 0         550803612197457920          AAPL
# 1         550803610825928706          AAPL
# 2         550803225113157632          AAPL
# 3         550802957370159104          AAPL
# 4         550802855129382912          AAPL
# ...                      ...           ...
# 4336440  1212158772015034369          TSLA
# 4336441  1212159099632267268          TSLA
# 4336442  1212159184931717120          TSLA
# 4336443  1212159838882533376          TSLA
# 4336444  1212160015332728833          TSLA
#
# [4336445 rows x 2 columns]

# %%
def df_by_co(myList):
    list_of_dfs = []
    for company in myList:
        cotweet_df = df.loc[df['ticker_symbol'] == company, :]
        list_of_dfs.append(cotweet_df)
    return list_of_dfs

# %%
df_list = df_by_co(['AAPL','GOOG','GOOGL','AMZN','MSFT', 'TSLA'])
df_list
# Out:
# [                    tweet_id ticker_symbol
#  0         550803612197457920          AAPL
#  1         550803610825928706          AAPL
#  2         550803225113157632          AAPL
#  3         550802957370159104          AAPL
#  4         550802855129382912          AAPL
#  ...                      ...           ...
#  1425008  1212159254884433921          AAPL
#  1425009  1212159275637886976          AAPL
#  1425010  1212159765914079234          AAPL
#  1425011  1212160410692046849          AAPL
#  1425012  1212160477159206912          AAPL
#
#  [1425013 rows x 2 columns],
#                      tweet_id ticker_symbol
#  1425013   550447850857828352          GOOG
#  1425014   550449439631233026          GOOG
#  1425015   550453087731982336          GOOG
#  1425016   550461555423584257          GOOG
#  1425017   550463776437174272          GOOG
#  ...                      ...           ...
#  1817577  1212145509579837440          GOOG
#  1817578  1212146656335949824          GOOG
# ...

# %%
def df_to_csv(myList, company):
    i = 0
    for df in myList:
        df.to_csv(f'./tweet_by_co/tweet_info{company[i]}.csv')
        i+=1

# %%
df_to_csv(df_list,['AAPL','GOOG','GOOGL','AMZN','MSFT', 'TSLA'])
