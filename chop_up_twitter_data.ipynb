# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('tweet_data.csv')
df
# Out:
#                     tweet_id           writer   post_date  \
# 0         550441509175443456  VisualStockRSRC  1420070457
# 1         550441672312512512      KeralaGuy77  1420070496
# 2         550441732014223360      DozenStocks  1420070510
# 3         550442977802207232     ShowDreamCar  1420070807
# 4         550443807834402816     i_Know_First  1420071005
# ...                      ...              ...         ...
# 3717959  1212159765914079234        TEEELAZER  1577836383
# 3717960  1212159838882533376    ShortingIsFun  1577836401
# 3717961  1212160015332728833      Commuternyc  1577836443
# 3717962  1212160410692046849      MoriaCrypto  1577836537
# 3717963  1212160477159206912         treabase  1577836553
#
#                                                       body  comment_num  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1        Insanity of today weirdo massive selling. $aap...            0
# ...

# %%
def time_converter(time):
    ts = int(time)
    return str(datetime.utcfromtimestamp(ts).strftime('%Y'))

# %%
df['post_date'] =df['post_date'].map(time_converter)

# %%
df
# Out:
#                     tweet_id           writer post_date  \
# 0         550441509175443456  VisualStockRSRC      2015
# 1         550441672312512512      KeralaGuy77      2015
# 2         550441732014223360      DozenStocks      2015
# 3         550442977802207232     ShowDreamCar      2015
# 4         550443807834402816     i_Know_First      2015
# ...                      ...              ...       ...
# 3717959  1212159765914079234        TEEELAZER      2019
# 3717960  1212159838882533376    ShortingIsFun      2019
# 3717961  1212160015332728833      Commuternyc      2019
# 3717962  1212160410692046849      MoriaCrypto      2019
# 3717963  1212160477159206912         treabase      2019
#
#                                                       body  comment_num  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1        Insanity of today weirdo massive selling. $aap...            0
# 2        S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# ...

# %%
def df_by_year(myList):
    list_of_dfs = []
    for year in myList:
        my_df = df.loc[df['post_date'] == year, :]
        list_of_dfs.append(my_df)
    return list_of_dfs

# %%
df_list = df_by_year(['2015','2016','2017','2018','2019'])
df_list
# Out:
# [                  tweet_id           writer post_date  \
#  0       550441509175443456  VisualStockRSRC      2015
#  1       550441672312512512      KeralaGuy77      2015
#  2       550441732014223360      DozenStocks      2015
#  3       550442977802207232     ShowDreamCar      2015
#  4       550443807834402816     i_Know_First      2015
#  ...                    ...              ...       ...
#  727891  682711958483808257       IBD_NGondo      2015
#  727892  682712177963347968      AMTrading24      2015
#  727893  682712545002520576   roadrunnergreg      2015
#  727894  682712548232187905      GregsHealth      2015
#  727895  682712552338370560  ShayneHeffernan      2015
#
#                                                       body  comment_num  \
#  0       lx21 made $10,008  on $AAPL -Check it out! htt...            0
#  1       Insanity of today weirdo massive selling. $aap...            0
#  2       S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# ...

# %%
def df_to_csv(myList, years):
    i = 0
    for df in myList:
        df.to_csv(f'./tweet_data_by_year/tweet_data{years[i]}.csv')
        i+=1

# %%
df_to_csv(df_list,['2015','2016','2017','2018','2019'])
